# %% [markdown]
# <a href="https://colab.research.google.com/github/MorshedulHoque/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/CSV Dataset/shooting-1982-2023.csv")

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.9/dist-packages/pandas/__init__.py'>

# %% [markdown]
# **First 5 data**

# %%
df.head()
# Out:
#                                   case                   location      date  \
# 0  Nashville religious school shooting              Nashville, TN   3-27-23
# 1   Michigan State University shooting     East Lansing, Michigan   2-13-23
# 2         Half Moon Bay spree shooting  Half Moon Bay, California   1-23-23
# 3        LA dance studio mass shooting  Monterey Park, California   1-21-23
# 4            Virginia Walmart shooting       Chesapeake, Virginia  11-22-22
#
#                                              summary  fatalities injured  \
# 0  Audrey Hale, 28, who was a former student at t...           6       1
# 1  Anthony D. McRae, 43, opened fire at Berkey Ha...           3       5
# 2  Chunli Zhao, 67, suspected of carrying out the...           7       1
# 3  Huu Can Tran, 72, fled the scene in a white va...          11      10
# 4  Andre Bing, 31, who worked as a supervisor at ...           6       6
#
# ...

# %% [markdown]
# **Last 5 data**

# %%
df.tail()
# Out:
#                                       case                location  \
# 136        Shopping centers spree killings       Palm Bay, Florida
# 137  United States Postal Service shooting        Edmond, Oklahoma
# 138         San Ysidro McDonald's massacre  San Ysidro, California
# 139              Dallas nightclub shooting           Dallas, Texas
# 140                  Welding shop shooting          Miami, Florida
#
#            date                                            summary  \
# 136  23-04-1987  Retired librarian William Cruse, 59, was paran...
# 137  20-08-1986  Postal worker Patrick Sherrill, 44, opened fir...
# 138  18-07-1984  James Oliver Huberty, 41, opened fire in a McD...
# 139  29-06-1984  Abdelkrim Belachheb, 39, opened fire at an ups...
# 140  20-08-1982  Junior high school teacher Carl Robert Brown, ...
#
#      fatalities injured total_victims location.1 age_of_shooter  \
# 136           6      14            20      Other             59
# ...

# %% [markdown]
# **First 3 records**

# %%
df.head(3)
# Out:
#                                   case                   location     date  \
# 0  Nashville religious school shooting              Nashville, TN  3-27-23
# 1   Michigan State University shooting     East Lansing, Michigan  2-13-23
# 2         Half Moon Bay spree shooting  Half Moon Bay, California  1-23-23
#
#                                              summary  fatalities injured  \
# 0  Audrey Hale, 28, who was a former student at t...           6       1
# 1  Anthony D. McRae, 43, opened fire at Berkey Ha...           3       5
# 2  Chunli Zhao, 67, suspected of carrying out the...           7       1
#
#   total_victims location.1 age_of_shooter prior_signs_mental_health_issues  \
# 0             6     School             28                                -
# 1             8     School             43                                -
# 2             8  workplace             67                                -
#
#    ... weapons_obtained_legally where_obtained  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_csv("Test.csv")

# %%
pd.read_csv("/content/Test.csv")
# Out:
#      Unnamed: 0                                   case  \
# 0             0    Nashville religious school shooting
# 1             1     Michigan State University shooting
# 2             2           Half Moon Bay spree shooting
# 3             3          LA dance studio mass shooting
# 4             4              Virginia Walmart shooting
# ..          ...                                    ...
# 136         136        Shopping centers spree killings
# 137         137  United States Postal Service shooting
# 138         138         San Ysidro McDonald's massacre
# 139         139              Dallas nightclub shooting
# 140         140                  Welding shop shooting
#
#                       location        date  \
# 0                Nashville, TN     3-27-23
# 1       East Lansing, Michigan     2-13-23
# 2    Half Moon Bay, California     1-23-23
# 3    Monterey Park, California     1-21-23
# 4         Chesapeake, Virginia    11-22-22
# ...

# %%
df
# Out:
#                                       case                   location  \
# 0      Nashville religious school shooting              Nashville, TN
# 1       Michigan State University shooting     East Lansing, Michigan
# 2             Half Moon Bay spree shooting  Half Moon Bay, California
# 3            LA dance studio mass shooting  Monterey Park, California
# 4                Virginia Walmart shooting       Chesapeake, Virginia
# ..                                     ...                        ...
# 136        Shopping centers spree killings          Palm Bay, Florida
# 137  United States Postal Service shooting           Edmond, Oklahoma
# 138         San Ysidro McDonald's massacre     San Ysidro, California
# 139              Dallas nightclub shooting              Dallas, Texas
# 140                  Welding shop shooting             Miami, Florida
#
#            date                                            summary  \
# ...

# %% [markdown]
# **This dataset is separated by "#". So, the dataset is not showing in a structured way.**

# %%
pd.read_csv("/content/drive/MyDrive/data.csv")
# Out:
#     Name#"Users"#"Facebook_Users%"#"Date_of_Data"#"Population"
# 0    India#"416.6M"#"29.16%"#"2021-06"#"1#428#627#663"
# 1    United States#"240M"#"70.59%"#"2020-12"#"339#9...
# 2    Indonesia#"176.5M"#"63.6%"#"2021-06"#"277#534#...
# 3       Brazil#"139M"#"64.23%"#"2020-12"#"216#422#446"
# 4    Philippines#"91M"#"77.55%"#"2021-06"#"117#337#...
# ..                                                 ...
# 221    Cook Islands#"2.7K"#"15.84%"#"2020-12"#"17#044"
# 222       Montserrat#"2.6K"#"59.28%"#"2020-12"#"4#386"
# 223              Niue#"820"#"42.38%"#"2020-12"#"1#935"
# 224       Vatican City#"799"#"154.25%"#"2020-12"#"518"
# 225           Tokelau#"410"#"21.66%"#"2020-12"#"1#893"
#
# [226 rows x 1 columns]

# %% [markdown]
# **Here, we use separator. By default, the fuction use "," seperator. As our dataset is separated by "#", we use "sep" attribute to define the separator.**

# %%
dff = pd.read_csv("/content/drive/MyDrive/data.csv", sep = "#")

# %%
dff
# Out:
#               Name   Users Facebook_Users% Date_of_Data     Population
# 0            India  416.6M          29.16%      2021-06  1#428#627#663
# 1    United States    240M          70.59%      2020-12    339#996#563
# 2        Indonesia  176.5M           63.6%      2021-06    277#534#122
# 3           Brazil    139M          64.23%      2020-12    216#422#446
# 4      Philippines     91M          77.55%      2021-06    117#337#368
# ..             ...     ...             ...          ...            ...
# 221   Cook Islands    2.7K          15.84%      2020-12         17#044
# 222     Montserrat    2.6K          59.28%      2020-12          4#386
# 223           Niue     820          42.38%      2020-12          1#935
# 224   Vatican City     799         154.25%      2020-12            518
# 225        Tokelau     410          21.66%      2020-12          1#893
#
# [226 rows x 5 columns]

# %% [markdown]
# **Usually, the first row of the dataset is used as header by default. But we can use the first column of the dataset as our data if we need.**

# %%
pd.read_csv("/content/drive/MyDrive/data.csv", sep="#", header=None)
# Out:
#                  0       1                2             3              4
# 0             Name   Users  Facebook_Users%  Date_of_Data     Population
# 1            India  416.6M           29.16%       2021-06  1#428#627#663
# 2    United States    240M           70.59%       2020-12    339#996#563
# 3        Indonesia  176.5M            63.6%       2021-06    277#534#122
# 4           Brazil    139M           64.23%       2020-12    216#422#446
# ..             ...     ...              ...           ...            ...
# 222   Cook Islands    2.7K           15.84%       2020-12         17#044
# 223     Montserrat    2.6K           59.28%       2020-12          4#386
# 224           Niue     820           42.38%       2020-12          1#935
# 225   Vatican City     799          154.25%       2020-12            518
# 226        Tokelau     410           21.66%       2020-12          1#893
#
# [227 rows x 5 columns]

# %% [markdown]
# **We can also change the column name if we need.**

# %%
pd.read_csv("/content/drive/MyDrive/data.csv", sep="#", header=None, names=['a', 'b', 'c', 'd', 'e'])
# Out:
#                  a       b                c             d              e
# 0             Name   Users  Facebook_Users%  Date_of_Data     Population
# 1            India  416.6M           29.16%       2021-06  1#428#627#663
# 2    United States    240M           70.59%       2020-12    339#996#563
# 3        Indonesia  176.5M            63.6%       2021-06    277#534#122
# 4           Brazil    139M           64.23%       2020-12    216#422#446
# ..             ...     ...              ...           ...            ...
# 222   Cook Islands    2.7K           15.84%       2020-12         17#044
# 223     Montserrat    2.6K           59.28%       2020-12          4#386
# 224           Niue     820           42.38%       2020-12          1#935
# 225   Vatican City     799          154.25%       2020-12            518
# 226        Tokelau     410           21.66%       2020-12          1#893
#
# [227 rows x 5 columns]

# %%
df.describe()
# Out:
#        fatalities         year
# count  141.000000   141.000000
# mean     7.808511  2010.382979
# std      7.463162    10.796600
# min      3.000000  1982.000000
# 25%      4.000000  2005.000000
# 50%      6.000000  2014.000000
# 75%      8.000000  2018.000000
# max     58.000000  2023.000000

# %%
df.dtypes
# Out:
# case                                object
# location                            object
# date                                object
# summary                             object
# fatalities                           int64
# injured                             object
# total_victims                       object
# location.1                          object
# age_of_shooter                      object
# prior_signs_mental_health_issues    object
# mental_health_details               object
# weapons_obtained_legally            object
# where_obtained                      object
# weapon_type                         object
# weapon_details                      object
# race                                object
# gender                              object
# latitude                            object
# longitude                           object
# type                                object
# year                                 int64
# dtype: object

# %%
df.columns
# Out:
# Index(['case', 'location', 'date', 'summary', 'fatalities', 'injured',
#        'total_victims', 'location.1', 'age_of_shooter',
#        'prior_signs_mental_health_issues', 'mental_health_details',
#        'weapons_obtained_legally', 'where_obtained', 'weapon_type',
#        'weapon_details', 'race', 'gender', 'latitude', 'longitude', 'type',
#        'year'],
#       dtype='object')

# %%
df['case']
# Out:
# 0        Nashville religious school shooting
# 1         Michigan State University shooting
# 2               Half Moon Bay spree shooting
# 3              LA dance studio mass shooting
# 4                  Virginia Walmart shooting
#                        ...
# 136          Shopping centers spree killings
# 137    United States Postal Service shooting
# 138           San Ysidro McDonald's massacre
# 139                Dallas nightclub shooting
# 140                    Welding shop shooting
# Name: case, Length: 141, dtype: object

# %%
type(df['case'])
# Out:
# pandas.core.series.Series

# %%
df[['case']]
# Out:
#                                       case
# 0      Nashville religious school shooting
# 1       Michigan State University shooting
# 2             Half Moon Bay spree shooting
# 3            LA dance studio mass shooting
# 4                Virginia Walmart shooting
# ..                                     ...
# 136        Shopping centers spree killings
# 137  United States Postal Service shooting
# 138         San Ysidro McDonald's massacre
# 139              Dallas nightclub shooting
# 140                  Welding shop shooting
#
# [141 rows x 1 columns]

# %%
type(df[['case']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Here, we find an error because we can not show multiple columns in series datatype. We need to convert it to dataframe.**

# %%
df['case','location']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('case', 'location')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[['case','location']]
# Out:
#                                       case                   location
# 0      Nashville religious school shooting              Nashville, TN
# 1       Michigan State University shooting     East Lansing, Michigan
# 2             Half Moon Bay spree shooting  Half Moon Bay, California
# 3            LA dance studio mass shooting  Monterey Park, California
# 4                Virginia Walmart shooting       Chesapeake, Virginia
# ..                                     ...                        ...
# 136        Shopping centers spree killings          Palm Bay, Florida
# 137  United States Postal Service shooting           Edmond, Oklahoma
# 138         San Ysidro McDonald's massacre     San Ysidro, California
# 139              Dallas nightclub shooting              Dallas, Texas
# 140                  Welding shop shooting             Miami, Florida
#
# [141 rows x 2 columns]

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # **Json Data**

# %%
import requests

# %% [markdown]
# **We can check the Json data in Json viewers websites**

# %%
res = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52712',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52712/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52712/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52712/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52712',
#   'id': 1672159532,
#   'node_id': 'I_kwDOAA0YD85jqyEs',
#   'number': 52712,
#   'title': 'BUG: Setting values on df with added column has no effect (pandas 2.0 regression)',
#   'user': {'login': 'stefanv',
#    'id': 45071,
#    'node_id': 'MDQ6VXNlcjQ1MDcx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45071?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stefanv',
#    'html_url': 'https://github.com/stefanv',
# ...

# %%
type(js)
# Out:
# list

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52712',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52712/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52712/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52712/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/52712',
#  'id': 1672159532,
#  'node_id': 'I_kwDOAA0YD85jqyEs',
#  'number': 52712,
#  'title': 'BUG: Setting values on df with added column has no effect (pandas 2.0 regression)',
#  'user': {'login': 'stefanv',
#   'id': 45071,
#   'node_id': 'MDQ6VXNlcjQ1MDcx',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/45071?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/stefanv',
#   'html_url': 'https://github.com/stefanv',
# ...

# %%
js[0]['title']
# Out:
# 'BUG: Setting values on df with added column has no effect (pandas 2.0 regression)'

# %%
for i in range(len(js)):
  print(js[i]['title'])
# Out:
# BUG: Setting values on df with added column has no effect (pandas 2.0 regression)
# PDEP-10: Add pyarrow as a required dependency
# BUG: groupby.resample index is 32-bit on 64-bit Windows when grouping by Python ints
# BUILD:  ImportError in instalation.
# REF: Styler.applymap -> map
# ENH: Better dtype inference for reductions on dataframes
# BUG: DatetimeTZDtype.base always returns dtype with ns resolution
# TST: setitem preserving period[D] dtype
# PERF: pd.concat is slower for all-nan object-dtyped columns than float equivalents
# BUG: pd.api.types.is_scalar reports `True` for Troch tensors
# DEV: adding codespace configuration
# BUG: fix the value error when using read_csv with "," as decimal point and pd.Float64Dtype()
# CI: Combine unit test workflows
# CI: Consolidate more comment command workflows
# BUG: ValueError when looking up docstring
# BUG: DataFrame.to_string() creates extra space for string dtypes in pandas >=2.0
# ...

# %%
len(js)
# Out:
# 30

# %% [markdown]
# **We can covert the Json data to tabular format. **

# %%
pd.DataFrame(js,columns=['id','url','title'])
# Out:
#             id                                                url  \
# 0   1672159532  https://api.github.com/repos/pandas-dev/pandas...
# 1   1672025129  https://api.github.com/repos/pandas-dev/pandas...
# 2   1671959245  https://api.github.com/repos/pandas-dev/pandas...
# 3   1671796774  https://api.github.com/repos/pandas-dev/pandas...
# 4   1671719085  https://api.github.com/repos/pandas-dev/pandas...
# 5   1671715745  https://api.github.com/repos/pandas-dev/pandas...
# 6   1671656829  https://api.github.com/repos/pandas-dev/pandas...
# 7   1671631980  https://api.github.com/repos/pandas-dev/pandas...
# 8   1671509212  https://api.github.com/repos/pandas-dev/pandas...
# 9   1671490097  https://api.github.com/repos/pandas-dev/pandas...
# 10  1671001957  https://api.github.com/repos/pandas-dev/pandas...
# 11  1670399913  https://api.github.com/repos/pandas-dev/pandas...
# 12  1670375501  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js[0]['user']
# Out:
# {'login': 'stefanv',
#  'id': 45071,
#  'node_id': 'MDQ6VXNlcjQ1MDcx',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/45071?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/stefanv',
#  'html_url': 'https://github.com/stefanv',
#  'followers_url': 'https://api.github.com/users/stefanv/followers',
#  'following_url': 'https://api.github.com/users/stefanv/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/stefanv/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/stefanv/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/stefanv/subscriptions',
#  'organizations_url': 'https://api.github.com/users/stefanv/orgs',
#  'repos_url': 'https://api.github.com/users/stefanv/repos',
#  'events_url': 'https://api.github.com/users/stefanv/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/stefanv/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
user_data = []
for i in range(len(js)):
  user_data.append(js[i]['user'])
  #print(js[i]['user'])
  print(user_data)
# Out:
# [{'login': 'stefanv', 'id': 45071, 'node_id': 'MDQ6VXNlcjQ1MDcx', 'avatar_url': 'https://avatars.githubusercontent.com/u/45071?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/stefanv', 'html_url': 'https://github.com/stefanv', 'followers_url': 'https://api.github.com/users/stefanv/followers', 'following_url': 'https://api.github.com/users/stefanv/following{/other_user}', 'gists_url': 'https://api.github.com/users/stefanv/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/stefanv/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/stefanv/subscriptions', 'organizations_url': 'https://api.github.com/users/stefanv/orgs', 'repos_url': 'https://api.github.com/users/stefanv/repos', 'events_url': 'https://api.github.com/users/stefanv/events{/privacy}', 'received_events_url': 'https://api.github.com/users/stefanv/received_events', 'type': 'User', 'site_admin': False}]
# ...

# %%
 user = pd.DataFrame(user_data)

# %%
user
# Out:
#             login         id               node_id  \
# 0         stefanv      45071      MDQ6VXNlcjQ1MDcx
# 1       mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 2      rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 3         evrocha   99438093          U_kgDOBe1ODQ
# 4        attack68   24256554  MDQ6VXNlcjI0MjU2NTU0
# 5      topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 6          shwina    3190405  MDQ6VXNlcjMxOTA0MDU=
# 7           srkds   61644078  MDQ6VXNlcjYxNjQ0MDc4
# 8             zbs    1444551  MDQ6VXNlcjE0NDQ1NTE=
# 9          shwina    3190405  MDQ6VXNlcjMxOTA0MDU=
# 10       noatamir    6564007  MDQ6VXNlcjY1NjQwMDc=
# 11         hxy450  100548919          U_kgDOBf5BNw
# 12      mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 13      mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 14  PhilipYip1988   56493395  MDQ6VXNlcjU2NDkzMzk1
# 15   samuelchodur     752993  MDQ6VXNlcjc1Mjk5Mw==
# 16     rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# ...

# %%
user['login']
# Out:
# 0           stefanv
# 1         mroeschke
# 2        rhshadrach
# 3           evrocha
# 4          attack68
# 5        topper-123
# 6            shwina
# 7             srkds
# 8               zbs
# 9            shwina
# 10         noatamir
# 11           hxy450
# 12        mroeschke
# 13        mroeschke
# 14    PhilipYip1988
# 15     samuelchodur
# 16       rhshadrach
# 17       rhshadrach
# 18         lusolorz
# 19     jbrockmendel
# 20         attack68
# 21        lithomas1
# 22       lukemanley
# 23        mroeschke
# 24     jbrockmendel
# 25      apuapaquola
# 26       pettzilla1
# 27     MarcoGorelli
# 28      ELHoussineT
# 29       fangchenli
# Name: login, dtype: object

# %%
user[['login']]
# Out:
#             login
# 0         stefanv
# 1       mroeschke
# 2      rhshadrach
# 3         evrocha
# 4        attack68
# 5      topper-123
# 6          shwina
# 7           srkds
# 8             zbs
# 9          shwina
# 10       noatamir
# 11         hxy450
# 12      mroeschke
# 13      mroeschke
# 14  PhilipYip1988
# 15   samuelchodur
# 16     rhshadrach
# 17     rhshadrach
# 18       lusolorz
# 19   jbrockmendel
# 20       attack68
# 21      lithomas1
# 22     lukemanley
# 23      mroeschke
# 24   jbrockmendel
# 25    apuapaquola
# 26     pettzilla1
# 27   MarcoGorelli
# 28    ELHoussineT
# 29     fangchenli

# %%
type(user[['login']])
# Out:
# pandas.core.frame.DataFrame

# %%
sorted(user['login'])
# Out:
# ['ELHoussineT',
#  'MarcoGorelli',
#  'PhilipYip1988',
#  'apuapaquola',
#  'attack68',
#  'attack68',
#  'evrocha',
#  'fangchenli',
#  'hxy450',
#  'jbrockmendel',
#  'jbrockmendel',
#  'lithomas1',
#  'lukemanley',
#  'lusolorz',
#  'mroeschke',
#  'mroeschke',
#  'mroeschke',
#  'mroeschke',
#  'noatamir',
#  'pettzilla1',
#  'rhshadrach',
#  'rhshadrach',
#  'rhshadrach',
#  'samuelchodur',
#  'shwina',
#  'shwina',
#  'srkds',
#  'stefanv',
#  'topper-123',
#  'zbs']

# %%
user["Utsho"] = "Hoque"

# %%
user
# Out:
#             login         id               node_id  \
# 0         stefanv      45071      MDQ6VXNlcjQ1MDcx
# 1       mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 2      rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 3         evrocha   99438093          U_kgDOBe1ODQ
# 4        attack68   24256554  MDQ6VXNlcjI0MjU2NTU0
# 5      topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 6          shwina    3190405  MDQ6VXNlcjMxOTA0MDU=
# 7           srkds   61644078  MDQ6VXNlcjYxNjQ0MDc4
# 8             zbs    1444551  MDQ6VXNlcjE0NDQ1NTE=
# 9          shwina    3190405  MDQ6VXNlcjMxOTA0MDU=
# 10       noatamir    6564007  MDQ6VXNlcjY1NjQwMDc=
# 11         hxy450  100548919          U_kgDOBf5BNw
# 12      mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 13      mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 14  PhilipYip1988   56493395  MDQ6VXNlcjU2NDkzMzk1
# 15   samuelchodur     752993  MDQ6VXNlcjc1Mjk5Mw==
# 16     rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# ...

# %% [markdown]
# **"Categorical" shows how many categories are there**

# %%
pd.Categorical(user['login'])
# Out:
# ['stefanv', 'mroeschke', 'rhshadrach', 'evrocha', 'attack68', ..., 'apuapaquola', 'pettzilla1', 'MarcoGorelli', 'ELHoussineT', 'fangchenli']
# Length: 30
# Categories (22, object): ['ELHoussineT', 'MarcoGorelli', 'PhilipYip1988', 'apuapaquola', ..., 'srkds',
#                           'stefanv', 'topper-123', 'zbs']

# %%
user['login'].unique()
# Out:
# array(['stefanv', 'mroeschke', 'rhshadrach', 'evrocha', 'attack68',
#        'topper-123', 'shwina', 'srkds', 'zbs', 'noatamir', 'hxy450',
#        'PhilipYip1988', 'samuelchodur', 'lusolorz', 'jbrockmendel',
#        'lithomas1', 'lukemanley', 'apuapaquola', 'pettzilla1',
#        'MarcoGorelli', 'ELHoussineT', 'fangchenli'], dtype=object)

# %%
user['login'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: login, dtype: bool

# %%
html_data=pd.read_html('''https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool
''')

# %%
html_data[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...
